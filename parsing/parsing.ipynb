# %%
from ycharts_parser import *

# %%
username = 'pwc161119@gmail.com'
password = '1Q2s3e4f'
parser = Parser(username, password)

# %%
macros = [
    'https://ycharts.com/indicators/us_consumer_price_index',
    'https://ycharts.com/indicators/us_gdp',
    'https://ycharts.com/indicators/us_core_inflation_rate',
    'https://ycharts.com/indicators/us_unemployment_rate',
    'https://ycharts.com/indicators/us_total_population',
    'https://ycharts.com/indicators/us_producer_price_index',
    'https://ycharts.com/indicators/vix_volatility_index',
    'https://ycharts.com/indicators/brent_crude_oil_spot_price',
    'https://ycharts.com/indicators/energy_index_world_bank',
    'https://ycharts.com/indicators/world_crude_oil_production',
    'https://ycharts.com/indicators/us_crude_oil_production',
    'https://ycharts.com/indicators/us_retail_diesel_price',
    'https://ycharts.com/indicators/us_gas_price',
    'https://ycharts.com/indicators/target_federal_funds_rate_upper_limit',
    'https://ycharts.com/indicators/us_producer_price_index_fabricated_metal_product_manufacturing',
    'https://ycharts.com/indicators/us_total_vehicle_sales',
    'https://ycharts.com/indicators/us_retail_sales',
    'https://ycharts.com/indicators/us_producer_price_index_steel_investment_foundries',
    'https://ycharts.com/indicators/copper_price',
    'https://ycharts.com/indicators/aluminum_price',
    'https://ycharts.com/indicators/nickel_price',
    'https://ycharts.com/indicators/iron_ore_spot_price_any_origin'
]

# %%
index_list = [
    ('https://ycharts.com/indices/%5EDJA/level', '5EDJA'),
    ('https://ycharts.com/indices/%5EIXIC/level', '5EIXIC'),
    ('https://ycharts.com/indices/%5ESP6OGDSI/level', '5ESP6OGDSI'),
    ('https://ycharts.com/indices/%5EMSW/level', '5EMSW'),
    ('https://ycharts.com/indices/%5ESPX/level', '5ESPX'),
    ('https://ycharts.com/indices/%5EMSEMURE/level', '5EMSEMURE') #поменялось
]

# %%
for url, name in index_list:
    df = parser.get_macro(url, index=True)
    df.to_csv('index/' + name + '.csv' , index=False)

# %%
for url in macros:
    df = parser.get_macro(url)
    name = df.columns[1]
    df.to_csv('macro/' + name + '.csv', index=False)

# %%
wrong = [
    'BHGE',
    'TSO',
    'TVE',
]

# %%
tickers = [
    'APA',
    'COG',
    'CVX',
    'COP',
    'EOG',
    'XOM',
    'HES',
    'MUR',
    'OXY',
    'SUN',
    'VLO',
    'BA',
    'LMT',
    'AAL',
    'DAL',
    'JBLU',
    'LUV',
    'HON',
    'RTN',
    'UTX',
    'GE',
    'FDX',
    'UPS',
    'AEP',
    'ETR',
    'PCG',
    'JE',
    'XEL',
    'ES',
    'AGR',
    'CPK',
    'NEE',
    'HE',
    'AVA',
    'IDA',
    'AEE',
    'DUK',
    'NI',
    'EXC'
]

# %%
# %%time
for ticker in tqdm(tickers):
    parser.get_all_financials(ticker)
# Out:
# ...
# CPU times: user 1min 27s, sys: 480 ms, total: 1min 27s
# Wall time: 30min 8s

# %%
# %%time
for ticker in tqdm(tickers[2:]):
    parser.get_all_key_stat(ticker)
    parser.get_all_financials(ticker)
    parser.save(ticker)
# Out:
# ...
# CVX показателей сохранено: 103
# ...
# COP показателей сохранено: 103
# ...
# EOG показателей сохранено: 103
# ...
# XOM показателей сохранено: 103
# ...
# ...
# ...
# NI показателей сохранено: 103
# ...
# EXC показателей сохранено: 103
#
# CPU times: user 1h 9min 54s, sys: 7min 23s, total: 1h 17min 18s
# Wall time: 1h 44min 55s

# %%
parser.get_all_prices(tickers)

# %%
for ticker in tickers:
    df = parser.price_data[ticker]
    df.to_csv('Data/' + ticker + '/price.csv', index=False)
